# %%
def fcfs(processes):
    start_times = [0] * len(processes)
    completion_times = [0] * len(processes)
    turnaround_times = [0] * len(processes)
    waiting_times = [0] * len(processes)
    
    current_time = 0
    total_waiting_time = 0
    total_turnaround_time = 0
    
    # Calculate start time, completion time, turnaround time, waiting time
    for i, (name, arrival_time, cpu_time) in enumerate(processes):
        if current_time < arrival_time:
            current_time = arrival_time
        
        start_times[i] = current_time
        completion_times[i] = current_time + cpu_time
        turnaround_times[i] = completion_times[i] - arrival_time
        waiting_times[i] = start_times[i] - arrival_time
        
        total_waiting_time += waiting_times[i]
        total_turnaround_time += turnaround_times[i]
        
        current_time = completion_times[i]
    
    # Calculate makespan
    makespan = max(completion_times)
    
    # Calculate average waiting time and average turnaround time
    avg_waiting_time = total_waiting_time / len(processes)
    avg_turnaround_time = total_turnaround_time / len(processes)
    
    return start_times, completion_times, turnaround_times, waiting_times, makespan, avg_waiting_time, avg_turnaround_time

# Example usage:
processes = [
    ("P1", 0, 14),
    ("P2", 1, 25),
    ("P3", 2, 29),
    ("P4", 4, 10),
]

start_times, completion_times, turnaround_times, waiting_times, makespan, avg_waiting_time, avg_turnaround_time = fcfs(processes)

# Output results
print("Process\tStart Time\tCompletion Time\tTurnaround Time\tWaiting Time")
for i, (name, _, _) in enumerate(processes):
    print(f"{name}\t{start_times[i]}\t\t{completion_times[i]}\t\t{turnaround_times[i]}\t\t{waiting_times[i]}")

print(f"\nMakespan: {makespan}")
print(f"Average Waiting Time: {avg_waiting_time}")
print(f"Average Turnaround Time: {avg_turnaround_time}")
# Out:
# Process	Start Time	Completion Time	Turnaround Time	Waiting Time
# P1	0		14		14		0
# P2	14		39		38		13
# P3	39		68		66		37
# P4	68		78		74		64
#
# Makespan: 78
# Average Waiting Time: 28.5
# Average Turnaround Time: 48.0

# %%
# Read the dataset from the provided text file
with open("C:/Users/Muhammad Nouman/Downloads/GoCJ_Dataset_100.txt", "r") as file:
    dataset = [int(job) for job in file.read().split("\n")]

# Number of processors available
num_processors = 8

# List of jobs with their sizes and indices
jobs = [(i, size) for i, size in enumerate(dataset, start=1)]

print("Total number of jobs:", len(jobs))
print("Total number of jobs:", jobs)
# Out:
# Total number of jobs: 100
# Total number of jobs: [(1, 127000), (2, 83000), (3, 63000), (4, 63000), (5, 65000), (6, 15000), (7, 91000), (8, 85000), (9, 101000), (10, 40000), (11, 40000), (12, 712500), (13, 59000), (14, 113000), (15, 87000), (16, 53000), (17, 47000), (18, 127000), (19, 45000), (20, 27500), (21, 115000), (22, 525000), (23, 117000), (24, 105000), (25, 65000), (26, 77000), (27, 47000), (28, 89000), (29, 91000), (30, 105000), (31, 117000), (32, 51000), (33, 15000), (34, 337500), (35, 129000), (36, 47000), (37, 109000), (38, 109000), (39, 135000), (40, 89000), (41, 101000), (42, 95000), (43, 125000), (44, 127000), (45, 83000), (46, 900000), (47, 712500), (48, 83000), (49, 101000), (50, 59000), (51, 105000), (52, 59000), (53, 47000), (54, 125000), (55, 105000), (56, 712500), (57, 45000), (58, 109000), (59, 67000), (60, 61000), (61, 67000), (62, 127000), (63, 87000), (64, 107000), (65, 135000), (66, 101000), (67, 95000), (68, 127000), (69, 525000), (70, 51000), (71, 91000), (72, 91000), (73, 93000), (74, 63000), (75, 51000), (76, 91000), (77, 79000), (78, 77000), (79, 91000), (80, 111000), (81, 85000), (82, 71000), (83, 125000), (84, 712500), (85, 49000), (86, 47000), (87, 40000), (88, 87000), (89, 125000), (90, 75000), (91, 337500), (92, 61000), (93, 93000), (94, 49000), (95, 113000), (96, 115000), (97, 525000), (98, 55000), (99, 65000), (100, 79000)]

# %%
def mct_schedule(jobs, num_processors):
    # Sort jobs based on their processing time (job size)
    sorted_jobs = sorted(jobs, key=lambda x: x[1])
    
    # Initialize a list to track the completion time of each processor
    processor_completion_time = [0] * num_processors
    
    # Initialize a dictionary to store the schedule (processor: [job indices])
    schedule = {i: [] for i in range(num_processors)}
    
    # Assign each job to the processor with the earliest completion time
    for job_index, job_size in sorted_jobs:
        # Find the processor with the earliest completion time
        min_completion_time = min(processor_completion_time)
        processor_index = processor_completion_time.index(min_completion_time)
        
        # Assign the job to the processor
        schedule[processor_index].append(job_index)
        
        # Update the completion time of the processor
        processor_completion_time[processor_index] += job_size
    
    return schedule

# Run MCT scheduling algorithm
mct_schedule_result = mct_schedule(jobs, num_processors)

# Print the schedule
for processor, job_indices in mct_schedule_result.items():
    print(f"Processor {processor}: Jobs {job_indices}")
# Out:
# Processor 0: Jobs [6, 17, 70, 92, 61, 45, 40, 93, 30, 14, 83, 39, 47]
# Processor 1: Jobs [33, 27, 75, 3, 82, 48, 7, 42, 51, 95, 89, 65, 56]
# Processor 2: Jobs [20, 36, 16, 4, 90, 8, 29, 67, 55, 21, 1, 34, 84]
# Processor 3: Jobs [10, 53, 98, 74, 26, 81, 71, 9, 64, 96, 18, 91, 46]
# Processor 4: Jobs [11, 86, 13, 5, 78, 15, 72, 41, 37, 23, 44, 22]
# Processor 5: Jobs [87, 85, 50, 25, 77, 63, 76, 49, 38, 31, 62, 69]
# Processor 6: Jobs [19, 94, 52, 99, 100, 88, 79, 66, 58, 43, 68, 97]
# Processor 7: Jobs [57, 32, 60, 59, 2, 28, 73, 24, 80, 54, 35, 12]

# %%
def mct_sequential(jobs):
    # Sort jobs based on their processing time (job size)
    sorted_jobs = sorted(jobs, key=lambda x: x[1])
    
    # Initialize metrics
    start_times = {}
    completion_times = {}
    turnaround_times = {}
    waiting_times = {}
    makespan = 0
    
    # Assign each job to the processor with the earliest completion time
    current_time = 0
    for job_index, job_size in sorted_jobs:
        # Calculate start time
        start_times[job_index] = current_time
        
        # Update completion time and makespan
        completion_times[job_index] = current_time + job_size
        current_time += job_size
        makespan = max(makespan, completion_times[job_index])
    
    # Calculate turnaround time and waiting time
    total_turnaround_time = 0
    total_waiting_time = 0
    for job_index, _ in sorted_jobs:
        turnaround_times[job_index] = completion_times[job_index] - start_times[job_index]
        waiting_times[job_index] = start_times[job_index]
        total_turnaround_time += turnaround_times[job_index]
        total_waiting_time += waiting_times[job_index]
    
    # Calculate average waiting time and average turnaround time
    num_jobs = len(jobs)
    avg_waiting_time = total_waiting_time / num_jobs
    avg_turnaround_time = total_turnaround_time / num_jobs
    
    return start_times, completion_times, turnaround_times, waiting_times, makespan, avg_waiting_time, avg_turnaround_time

# Read the dataset from the provided text file
with open("C:/Users/Muhammad Nouman/Downloads/GoCJ_Dataset_100.txt", "r") as file:
    dataset = [int(job) for job in file.read().split("\n")]

# Create list of jobs
jobs = [(i, size) for i, size in enumerate(dataset, start=1)]

# Run MCT scheduling algorithm
start_times, completion_times, turnaround_times, waiting_times, makespan, avg_waiting_time, avg_turnaround_time = mct_sequential(jobs)

for job_index, _ in sorted(start_times.items(), key=lambda x: x[1]):
    print(f"Job {job_index}: Start Time: {start_times[job_index]}, Completion Time: {completion_times[job_index]}, Turnaround Time: {turnaround_times[job_index]}, Waiting Time: {waiting_times[job_index]}")

print(f"Makespan: {makespan}")
print(f"Average Waiting Time: {avg_waiting_time}")
print(f"Average Turnaround Time: {avg_turnaround_time}")
# Out:
# Job 6: Start Time: 0, Completion Time: 15000, Turnaround Time: 15000, Waiting Time: 0
# Job 33: Start Time: 15000, Completion Time: 30000, Turnaround Time: 15000, Waiting Time: 15000
# Job 20: Start Time: 30000, Completion Time: 57500, Turnaround Time: 27500, Waiting Time: 30000
# Job 10: Start Time: 57500, Completion Time: 97500, Turnaround Time: 40000, Waiting Time: 57500
# Job 11: Start Time: 97500, Completion Time: 137500, Turnaround Time: 40000, Waiting Time: 97500
# Job 87: Start Time: 137500, Completion Time: 177500, Turnaround Time: 40000, Waiting Time: 137500
# Job 19: Start Time: 177500, Completion Time: 222500, Turnaround Time: 45000, Waiting Time: 177500
# Job 57: Start Time: 222500, Completion Time: 267500, Turnaround Time: 45000, Waiting Time: 222500
# Job 17: Start Time: 267500, Completion Time: 314500, Turnaround Time: 47000, Waiting Time: 267500
# Job 27: Start Time: 314500, Completion Time: 361500, Turnaround Time: 47000, Waiting Time: 314500
# Job 36: Start Time: 361500, Completion Time: 408500, Turnaround Time: 47000, Waiting Time: 361500
# Job 53: Start Time: 408500, Completion Time: 455500, Turnaround Time: 47000, Waiting Time: 408500
# Job 86: Start Time: 455500, Completion Time: 502500, Turnaround Time: 47000, Waiting Time: 455500
# Job 85: Start Time: 502500, Completion Time: 551500, Turnaround Time: 49000, Waiting Time: 502500
# Job 94: Start Time: 551500, Completion Time: 600500, Turnaround Time: 49000, Waiting Time: 551500
# Job 32: Start Time: 600500, Completion Time: 651500, Turnaround Time: 51000, Waiting Time: 600500
# Job 70: Start Time: 651500, Completion Time: 702500, Turnaround Time: 51000, Waiting Time: 651500
# Job 75: Start Time: 702500, Completion Time: 753500, Turnaround Time: 51000, Waiting Time: 702500
# Job 16: Start Time: 753500, Completion Time: 806500, Turnaround Time: 53000, Waiting Time: 753500
# Job 98: Start Time: 806500, Completion Time: 861500, Turnaround Time: 55000, Waiting Time: 806500
# Job 13: Start Time: 861500, Completion Time: 920500, Turnaround Time: 59000, Waiting Time: 861500
# Job 50: Start Time: 920500, Completion Time: 979500, Turnaround Time: 59000, Waiting Time: 920500
# Job 52: Start Time: 979500, Completion Time: 1038500, Turnaround Time: 59000, Waiting Time: 979500
# Job 60: Start Time: 1038500, Completion Time: 1099500, Turnaround Time: 61000, Waiting Time: 1038500
# Job 92: Start Time: 1099500, Completion Time: 1160500, Turnaround Time: 61000, Waiting Time: 1099500
# Job 3: Start Time: 1160500, Completion Time: 1223500, Turnaround Time: 63000, Waiting Time: 1160500
# Job 4: Start Time: 1223500, Completion Time: 1286500, Turnaround Time: 63000, Waiting Time: 1223500
# Job 74: Start Time: 1286500, Completion Time: 1349500, Turnaround Time: 63000, Waiting Time: 1286500
# Job 5: Start Time: 1349500, Completion Time: 1414500, Turnaround Time: 65000, Waiting Time: 1349500
# Job 25: Start Time: 1414500, Completion Time: 1479500, Turnaround Time: 65000, Waiting Time: 1414500
# Job 99: Start Time: 1479500, Completion Time: 1544500, Turnaround Time: 65000, Waiting Time: 1479500
# Job 59: Start Time: 1544500, Completion Time: 1611500, Turnaround Time: 67000, Waiting Time: 1544500
# Job 61: Start Time: 1611500, Completion Time: 1678500, Turnaround Time: 67000, Waiting Time: 1611500
# Job 82: Start Time: 1678500, Completion Time: 1749500, Turnaround Time: 71000, Waiting Time: 1678500
# Job 90: Start Time: 1749500, Completion Time: 1824500, Turnaround Time: 75000, Waiting Time: 1749500
# Job 26: Start Time: 1824500, Completion Time: 1901500, Turnaround Time: 77000, Waiting Time: 1824500
# Job 78: Start Time: 1901500, Completion Time: 1978500, Turnaround Time: 77000, Waiting Time: 1901500
# Job 77: Start Time: 1978500, Completion Time: 2057500, Turnaround Time: 79000, Waiting Time: 1978500
# Job 100: Start Time: 2057500, Completion Time: 2136500, Turnaround Time: 79000, Waiting Time: 2057500
# Job 2: Start Time: 2136500, Completion Time: 2219500, Turnaround Time: 83000, Waiting Time: 2136500
# Job 45: Start Time: 2219500, Completion Time: 2302500, Turnaround Time: 83000, Waiting Time: 2219500
# Job 48: Start Time: 2302500, Completion Time: 2385500, Turnaround Time: 83000, Waiting Time: 2302500
# Job 8: Start Time: 2385500, Completion Time: 2470500, Turnaround Time: 85000, Waiting Time: 2385500
# Job 81: Start Time: 2470500, Completion Time: 2555500, Turnaround Time: 85000, Waiting Time: 2470500
# Job 15: Start Time: 2555500, Completion Time: 2642500, Turnaround Time: 87000, Waiting Time: 2555500
# Job 63: Start Time: 2642500, Completion Time: 2729500, Turnaround Time: 87000, Waiting Time: 2642500
# Job 88: Start Time: 2729500, Completion Time: 2816500, Turnaround Time: 87000, Waiting Time: 2729500
# Job 28: Start Time: 2816500, Completion Time: 2905500, Turnaround Time: 89000, Waiting Time: 2816500
# Job 40: Start Time: 2905500, Completion Time: 2994500, Turnaround Time: 89000, Waiting Time: 2905500
# Job 7: Start Time: 2994500, Completion Time: 3085500, Turnaround Time: 91000, Waiting Time: 2994500
# Job 29: Start Time: 3085500, Completion Time: 3176500, Turnaround Time: 91000, Waiting Time: 3085500
# Job 71: Start Time: 3176500, Completion Time: 3267500, Turnaround Time: 91000, Waiting Time: 3176500
# Job 72: Start Time: 3267500, Completion Time: 3358500, Turnaround Time: 91000, Waiting Time: 3267500
# Job 76: Start Time: 3358500, Completion Time: 3449500, Turnaround Time: 91000, Waiting Time: 3358500
# Job 79: Start Time: 3449500, Completion Time: 3540500, Turnaround Time: 91000, Waiting Time: 3449500
# Job 73: Start Time: 3540500, Completion Time: 3633500, Turnaround Time: 93000, Waiting Time: 3540500
# Job 93: Start Time: 3633500, Completion Time: 3726500, Turnaround Time: 93000, Waiting Time: 3633500
# Job 42: Start Time: 3726500, Completion Time: 3821500, Turnaround Time: 95000, Waiting Time: 3726500
# Job 67: Start Time: 3821500, Completion Time: 3916500, Turnaround Time: 95000, Waiting Time: 3821500
# Job 9: Start Time: 3916500, Completion Time: 4017500, Turnaround Time: 101000, Waiting Time: 3916500
# Job 41: Start Time: 4017500, Completion Time: 4118500, Turnaround Time: 101000, Waiting Time: 4017500
# Job 49: Start Time: 4118500, Completion Time: 4219500, Turnaround Time: 101000, Waiting Time: 4118500
# Job 66: Start Time: 4219500, Completion Time: 4320500, Turnaround Time: 101000, Waiting Time: 4219500
# Job 24: Start Time: 4320500, Completion Time: 4425500, Turnaround Time: 105000, Waiting Time: 4320500
# Job 30: Start Time: 4425500, Completion Time: 4530500, Turnaround Time: 105000, Waiting Time: 4425500
# Job 51: Start Time: 4530500, Completion Time: 4635500, Turnaround Time: 105000, Waiting Time: 4530500
# Job 55: Start Time: 4635500, Completion Time: 4740500, Turnaround Time: 105000, Waiting Time: 4635500
# Job 64: Start Time: 4740500, Completion Time: 4847500, Turnaround Time: 107000, Waiting Time: 4740500
# Job 37: Start Time: 4847500, Completion Time: 4956500, Turnaround Time: 109000, Waiting Time: 4847500
# Job 38: Start Time: 4956500, Completion Time: 5065500, Turnaround Time: 109000, Waiting Time: 4956500
# Job 58: Start Time: 5065500, Completion Time: 5174500, Turnaround Time: 109000, Waiting Time: 5065500
# Job 80: Start Time: 5174500, Completion Time: 5285500, Turnaround Time: 111000, Waiting Time: 5174500
# Job 14: Start Time: 5285500, Completion Time: 5398500, Turnaround Time: 113000, Waiting Time: 5285500
# Job 95: Start Time: 5398500, Completion Time: 5511500, Turnaround Time: 113000, Waiting Time: 5398500
# Job 21: Start Time: 5511500, Completion Time: 5626500, Turnaround Time: 115000, Waiting Time: 5511500
# Job 96: Start Time: 5626500, Completion Time: 5741500, Turnaround Time: 115000, Waiting Time: 5626500
# Job 23: Start Time: 5741500, Completion Time: 5858500, Turnaround Time: 117000, Waiting Time: 5741500
# Job 31: Start Time: 5858500, Completion Time: 5975500, Turnaround Time: 117000, Waiting Time: 5858500
# Job 43: Start Time: 5975500, Completion Time: 6100500, Turnaround Time: 125000, Waiting Time: 5975500
# Job 54: Start Time: 6100500, Completion Time: 6225500, Turnaround Time: 125000, Waiting Time: 6100500
# Job 83: Start Time: 6225500, Completion Time: 6350500, Turnaround Time: 125000, Waiting Time: 6225500
# Job 89: Start Time: 6350500, Completion Time: 6475500, Turnaround Time: 125000, Waiting Time: 6350500
# Job 1: Start Time: 6475500, Completion Time: 6602500, Turnaround Time: 127000, Waiting Time: 6475500
# Job 18: Start Time: 6602500, Completion Time: 6729500, Turnaround Time: 127000, Waiting Time: 6602500
# Job 44: Start Time: 6729500, Completion Time: 6856500, Turnaround Time: 127000, Waiting Time: 6729500
# Job 62: Start Time: 6856500, Completion Time: 6983500, Turnaround Time: 127000, Waiting Time: 6856500
# Job 68: Start Time: 6983500, Completion Time: 7110500, Turnaround Time: 127000, Waiting Time: 6983500
# Job 35: Start Time: 7110500, Completion Time: 7239500, Turnaround Time: 129000, Waiting Time: 7110500
# Job 39: Start Time: 7239500, Completion Time: 7374500, Turnaround Time: 135000, Waiting Time: 7239500
# Job 65: Start Time: 7374500, Completion Time: 7509500, Turnaround Time: 135000, Waiting Time: 7374500
# Job 34: Start Time: 7509500, Completion Time: 7847000, Turnaround Time: 337500, Waiting Time: 7509500
# Job 91: Start Time: 7847000, Completion Time: 8184500, Turnaround Time: 337500, Waiting Time: 7847000
# Job 22: Start Time: 8184500, Completion Time: 8709500, Turnaround Time: 525000, Waiting Time: 8184500
# Job 69: Start Time: 8709500, Completion Time: 9234500, Turnaround Time: 525000, Waiting Time: 8709500
# Job 97: Start Time: 9234500, Completion Time: 9759500, Turnaround Time: 525000, Waiting Time: 9234500
# Job 12: Start Time: 9759500, Completion Time: 10472000, Turnaround Time: 712500, Waiting Time: 9759500
# Job 47: Start Time: 10472000, Completion Time: 11184500, Turnaround Time: 712500, Waiting Time: 10472000
# Job 56: Start Time: 11184500, Completion Time: 11897000, Turnaround Time: 712500, Waiting Time: 11184500
# Job 84: Start Time: 11897000, Completion Time: 12609500, Turnaround Time: 712500, Waiting Time: 11897000
# Job 46: Start Time: 12609500, Completion Time: 13509500, Turnaround Time: 900000, Waiting Time: 12609500
# Makespan: 13509500
# Average Waiting Time: 3633130.0
# Average Turnaround Time: 135095.0
